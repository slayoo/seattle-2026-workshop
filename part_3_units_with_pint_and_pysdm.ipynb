# %% [markdown]
# [![launch on Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/slayoo/seattle-2026-workshop/blob/main/part_3_units_with_pint_and_pysdm.ipynb)

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip --quiet install open-atmos-jupyter-utils pint PySDM

# %% [markdown]
# # hacking aerosol-cloud μ-physics modeling concepts in Python
# ### (mini-workshop @Uni. Washington Seattle, Jan 2026)
#
# ### Part 3: dimensional analysis using Pint (and PySDM.physics)
#
# notebook authors (alphabetically):
# - Sylwester Arabas
# - Agnieszka Żaba
#
# This notebook ...

# %%
from PySDM.physics.dimensional_analysis import DimensionalAnalysis

with DimensionalAnalysis():
    c, SI = constants()

    p = 1000 * SI.hPa
    T = 300 * SI.K
    rho = p / c.R_d / T
    print(rho)
    assert rho.check("[density]")
# Out:
# 11.77444706866081 gram * hectopascal / joule

# %%
with DimensionalAnalysis():
    c, SI = constants()
    try:
        20 * SI.J + 10 * SI.K
    except:
        print("FAILED!")
# Out:
# FAILED!

# %%
TODO: 
- compatibility with SciPy solvers
- plots?
- conversions
- ...
